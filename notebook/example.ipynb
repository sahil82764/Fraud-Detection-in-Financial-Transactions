# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Sahil Khan\\OneDrive\\Desktop\\AI GRAD CERT\\aidi github\\AIDI 2005 - Capstone Project II\\Fraud-Detection-in-Financial-Transactions\\notebook'

# %%
df = pd.read_csv('c:\\Users\\Sahil Khan\\OneDrive\\Desktop\\AI GRAD CERT\\aidi github\\AIDI 2005 - Capstone Project II\\Fraud-Detection-in-Financial-Transactions\\Data\\output_file_1.csv')

# %%
df
# Out:
#        step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0         1   PAYMENT    9839.64  C1231006815       170136.0       160296.36
# 1         1   PAYMENT    1864.28  C1666544295        21249.0        19384.72
# 2         1  TRANSFER     181.00  C1305486145          181.0            0.00
# 3         1  CASH_OUT     181.00   C840083671          181.0            0.00
# 4         1   PAYMENT   11668.14  C2048537720        41554.0        29885.86
# ...     ...       ...        ...          ...            ...             ...
# 99995    10   PAYMENT    4020.66  C1410794718       159929.0       155908.34
# 99996    10   PAYMENT   18345.49   C744303677         6206.0            0.00
# 99997    10   CASH_IN  183774.91   C104331851        39173.0       222947.91
# 99998    10  CASH_OUT   82237.17   C707662966         6031.0            0.00
# 99999    10   PAYMENT   20096.56  C1868032458       110117.0        90020.44
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   step            100000 non-null  int64
#  1   type            100000 non-null  object
#  2   amount          100000 non-null  float64
#  3   nameOrig        100000 non-null  object
#  4   oldbalanceOrg   100000 non-null  float64
#  5   newbalanceOrig  100000 non-null  float64
#  6   nameDest        100000 non-null  object
#  7   oldbalanceDest  100000 non-null  float64
#  8   newbalanceDest  100000 non-null  float64
#  9   isFraud         100000 non-null  int64
#  10  isFlaggedFraud  100000 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 8.4+ MB

# %%
from collections import namedtuple

# %%
DataIngestionConfig = namedtuple('DataIngestionConfig',["","",""])

# %%
import glob
import os
import pandas as pd

# %%
csv_files = glob.glob(os.path.join(r"C:\\Users\\Sahil Khan\\OneDrive\Desktop\AI GRAD CERT\\aidi github\AIDI 2005 - Capstone Project II\\Fraud-Detection-in-Financial-Transactions\\Data", '*.csv'))
csv_files
# Out:
# ['C:\\\\Users\\\\Sahil Khan\\\\OneDrive\\Desktop\\AI GRAD CERT\\\\aidi github\\AIDI 2005 - Capstone Project II\\\\Fraud-Detection-in-Financial-Transactions\\\\Data\\output_file_1.csv',
#  'C:\\\\Users\\\\Sahil Khan\\\\OneDrive\\Desktop\\AI GRAD CERT\\\\aidi github\\AIDI 2005 - Capstone Project II\\\\Fraud-Detection-in-Financial-Transactions\\\\Data\\output_file_10.csv',
#  'C:\\\\Users\\\\Sahil Khan\\\\OneDrive\\Desktop\\AI GRAD CERT\\\\aidi github\\AIDI 2005 - Capstone Project II\\\\Fraud-Detection-in-Financial-Transactions\\\\Data\\output_file_11.csv',
#  'C:\\\\Users\\\\Sahil Khan\\\\OneDrive\\Desktop\\AI GRAD CERT\\\\aidi github\\AIDI 2005 - Capstone Project II\\\\Fraud-Detection-in-Financial-Transactions\\\\Data\\output_file_12.csv',
#  'C:\\\\Users\\\\Sahil Khan\\\\OneDrive\\Desktop\\AI GRAD CERT\\\\aidi github\\AIDI 2005 - Capstone Project II\\\\Fraud-Detection-in-Financial-Transactions\\\\Data\\output_file_13.csv',
# ...

# %%
frdTrns_data = []

# Read each CSV file into a DataFrame and append it to the list
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    frdTrns_data.append(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 8>()
#       5     df = pd.read_csv(csv_file)
#       6     frdTrns_data.append(df)
# ----> 8 frdTrns_data.head(10)
#
# AttributeError: 'list' object has no attribute 'head'

# %%
final_df = pd.concat(frdTrns_data, ignore_index=True)

# %%
final_df.head(50)
# Out:
#     step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0      1   PAYMENT    9839.64  C1231006815      170136.00       160296.36
# 1      1   PAYMENT    1864.28  C1666544295       21249.00        19384.72
# 2      1  TRANSFER     181.00  C1305486145         181.00            0.00
# 3      1  CASH_OUT     181.00   C840083671         181.00            0.00
# 4      1   PAYMENT   11668.14  C2048537720       41554.00        29885.86
# 5      1   PAYMENT    7817.71    C90045638       53860.00        46042.29
# 6      1   PAYMENT    7107.77   C154988899      183195.00       176087.23
# 7      1   PAYMENT    7861.64  C1912850431      176087.23       168225.59
# 8      1   PAYMENT    4024.36  C1265012928        2671.00            0.00
# 9      1     DEBIT    5337.77   C712410124       41720.00        36382.23
# 10     1     DEBIT    9644.94  C1900366749        4465.00            0.00
# 11     1   PAYMENT    3099.97   C249177573       20771.00        17671.03
# ...

# %%
from sklearn.model_selection import StratifiedShuffleSplit

strat_train_set = None
strat_test_set = None

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# %%
for train_index, test_index in split.split(final_df, final_df['isFraud']):
    strat_train_set = final_df.loc[train_index]
    strat_test_set = final_df.loc[test_index]

# %%
strat_test_set['isFraud'].value_counts()
# Out:
# 0    1270881
# 1       1643
# Name: isFraud, dtype: int64

# %%
final_df['isFraud'].value_counts()
# Out:
# 0    6354407
# 1       8213
# Name: isFraud, dtype: int64

# %%
file_name = os.listdir(raw_data_dir)[0]

logging.info(f"Reading csv file: [{raw_data_dir}]")

# Initialize an empty list to store DataFrames
frdTrns_data = []

# Read each CSV file into a DataFrame and append it to the list
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    frdTrns_data.append(df)

# Concatenate all DataFrames in the list into a single DataFrame
final_df = pd.concat(frdTrns_data, ignore_index=True)

# %%
file1 = pd.read_csv(r'C:\\Users\\Sahil Khan\\OneDrive\Desktop\AI GRAD CERT\\aidi github\AIDI 2005 - Capstone Project II\\Fraud-Detection-in-Financial-Transactions\\Data\\output_file_1.csv')

# %%
file2 = pd.read_csv(r'C:\\Users\\Sahil Khan\\OneDrive\Desktop\AI GRAD CERT\\aidi github\AIDI 2005 - Capstone Project II\\Fraud-Detection-in-Financial-Transactions\\Data\\output_file_2.csv')

# %%
file1.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
file2.head()
# Out:
#    step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0    10  CASH_OUT  578570.34  C1842020389           0.00            0.00
# 1    10   PAYMENT    3948.26   C924595278           0.00            0.00
# 2    10   PAYMENT    1990.85   C164024007       10117.51         8126.67
# 3    10   PAYMENT    3233.27  C1783742575        8126.67         4893.40
# 4    10   CASH_IN   43526.60   C508964499       36522.00        80048.60
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  C1750350389       782692.89      1735465.73        0               0
# 1  M1742045918            0.00            0.00        0               0
# 2  M1018772978            0.00            0.00        0               0
# 3   M559512713            0.00            0.00        0               0
# 4  C1329428979        32187.91            0.00        0               0
